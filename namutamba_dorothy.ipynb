# %%
import pandas as pd

# Dictionary of days and dates
days_dates = {
    "Monday": "2023-07-03",
    "Tuesday": "2023-07-04",
    "Wednesday": "2023-07-05",
    "Thursday": "2023-07-06",
    "Friday": "2023-07-07",
    "Saturday": "2023-07-08",
    "Sunday": "2023-07-09"
}

# Create a pandas Series from the dictionary
series_days_dates = pd.Series(days_dates)

# Display the pandas Series
print(series_days_dates)
# Out:
# Monday       2023-07-03
# Tuesday      2023-07-04
# Wednesday    2023-07-05
# Thursday     2023-07-06
# Friday       2023-07-07
# Saturday     2023-07-08
# Sunday       2023-07-09
# dtype: object

# %%
import pandas as pd
df = pd.read_csv('bse_dataset4.csv')
print(df)
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df.head()  # Display the first 5 rows of the DataFrame
df.head(10)  # Display the first 10 rows of the DataFrame
# Out:
#              Timestamp         gender   Age               emotion   YOB  CGPA  \
# 0  05/07/2023 09:38:39           Male  21.0               Content  2002  4.22
# 1  05/07/2023 09:38:57  Marabou stock  45.0                 Weird  2100   8.9
# 2  05/07/2023 09:39:09        Female   20.0                 Happy  2002  3.98
# 3  05/07/2023 09:39:12           Male  21.0                 Happy  2003  4.37
# 4  05/07/2023 09:39:14         Female  21.0                 Happy  2002  3.63
# 5                  NaN         Female  23.0                Happy   2000   3.8
# 6  05/07/2023 09:39:21         female  21.0            irritated   2001  3.88
# 7  05/07/2023 09:39:23        Female   22.0  In a state of wonder  2001  3.79
# 8  05/07/2023 09:39:26           Male  22.0                   Sad  2001   4.7
# 9  05/07/2023 09:39:27         Female  20.0                 happy  2002     4
#
#   Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df.tail()  # Display the last 5 rows of the DataFrame
df.tail(10)  # Display the last 10 rows of the DataFrame
# Out:
#                Timestamp  gender   Age      emotion   YOB     CGPA  \
# 159  05/07/2023 09:43:05    Male  22.0       Joyful  2001     4.08
# 160  05/07/2023 09:43:08  Female  21.0  Nonchalant   2002      4.5
# 161  05/07/2023 09:43:22    male  23.0      excited  2000     4.16
# 162  05/07/2023 09:43:36    male  21.0     stressed  2002      4.4
# 163  05/07/2023 09:43:56    Male  21.0      Relaxed  2001      4.5
# 164  05/07/2023 09:44:09    Male  22.0       Angry   1999      3.5
# 165  05/07/2023 09:44:14    male  23.0          sad  1999        4
# 166  05/07/2023 09:44:15    male  20.0         calm  2002      3.7
# 167  05/07/2023 09:44:35  Female  21.0          sad  2001      3.8
# 168  05/07/2023 09:45:13  Female  20.0        Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 159                                     Yes                      No
# 160                                     Yes                      No
# ...

# %%
df.info()  # Display information about the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           168 non-null    object
#  1   gender                                              169 non-null    object
#  2   Age                                                 167 non-null    float64
#  3   emotion                                             168 non-null    object
#  4   YOB                                                 169 non-null    object
#  5   CGPA                                                169 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             169 non-null    object
#  7   Do you have Depression?                             169 non-null    object
# ...

# %%
df.dropna()  # Remove rows with any NaN value
df.dropna(axis=1)  # Remove columns with any NaN value
# Out:
#             gender   YOB     CGPA Do you have a Girl Friend or BOY Friend  \
# 0             Male  2002     4.22                                      No
# 1    Marabou stock  2100      8.9                                     Yes
# 2          Female   2002     3.98                                      No
# 3             Male  2003     4.37                                      No
# 4           Female  2002     3.63                                      No
# ..             ...   ...      ...                                     ...
# 164           Male  1999      3.5                                    Yes
# 165           male  1999        4                                      no
# 166           male  2002      3.7                                     yes
# 167         Female  2001      3.8                                      no
# 168         Female  2022  4......                                      no
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# ...

# %%
df.fillna(0)  # Fill NaN values with 0
df.fillna(method='ffill')  # Forward fill NaN values with the previous non-null value
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...
